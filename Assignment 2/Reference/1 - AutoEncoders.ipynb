# %%
#SEED ALL for reproducibility
from numpy.random import seed
import tensorflow as tf

cherrypicked_seed = 1

seed(cherrypicked_seed)
tf.random.set_seed(cherrypicked_seed)

# %% [markdown]
# ### AutoEncoders

# %% [markdown]
# An autoencoder is an artificial neural network used for learning efficient representations of the input.
#
# The aim of an autoencoder is to learn a representation (encoding) for a set of data, typically for the purpose of dimensionality reduction.

# %% [markdown]
# <img src="https://miro.medium.com/max/3148/1*44eDEuZBEsmG_TCAKRI3Kw@2x.png" width="65%">

# %% [markdown]
# ### Reference
#
# Based on [https://blog.keras.io/building-autoencoders-in-keras.html](https://blog.keras.io/building-autoencoders-in-keras.html)

# %% [markdown]
# ---

# %% [markdown]
# ## Dataset

# %%
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model

from tensorflow.keras.datasets import fashion_mnist

import numpy as np

# %%
(X_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

X_train = X_train.astype('float32') / 255.
x_test = x_test.astype('float32') / 255.
X_train = X_train.reshape((len(X_train), np.prod(X_train.shape[1:])))
x_test = x_test.reshape((len(x_test), np.prod(x_test.shape[1:])))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
X_train.shape
# Out:
# (60000, 784)

# %% [markdown]
# ## Model Design

# %% [markdown]
# ### The main AE model

# %%
# this is the size of our encoded representations
encoding_dim = 32
activation = "relu"

# this is our input placeholder
input = Input(shape=(784,)) #28 x28

# hiddent layers
downsampling_hidden_1 = Dense(256, activation = activation, name = "downsampling_hidden_1")(input)

downsampling_hidden_2 = Dense(64, activation = activation, name = "downsampling_hidden_2")(downsampling_hidden_1)

# "encoded" is the encoded representation of the input
encoded = Dense(encoding_dim, activation=activation, name = "latent")(downsampling_hidden_2)

upsampling_hidden_1 = Dense(64, activation = activation, name = "upsampling_hidden_1")(encoded)

upsampling_hidden_2 = Dense(256, activation = activation, name = "upsampling_hidden_2")(upsampling_hidden_1)

# "decoded" is the lossy reconstruction of the input
decoded = Dense(784, activation='sigmoid', name = "decoder")(upsampling_hidden_2)

# this model maps an input to its reconstruction
autoencoder = Model(input, decoded)

autoencoder.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ downsampling_hidden_1 (Dense)        │ (None, 256)                 │         200,960 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ downsampling_hidden_2 (Dense)        │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ latent (Dense)                       │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ upsampling_hidden_1 (Dense)          │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ upsampling_hidden_2 (Dense)          │ (None, 256)                 │          16,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ decoder (Dense)                      │ (None, 784)                 │         201,488 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 439,728 (1.68 MB)
#  Trainable params: 439,728 (1.68 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### SubModels

# %% [markdown]
# The functional api allows to create **submodels**.
#
# Here we will instanciate two submodels, one responisble for the encoding  section of the AE (**encoder**), and the other for the decoding section (**decoder**).

# %%
# this model maps an input to its encoded representation
encoder_model = Model(input, encoded)
encoder_model.summary()
# Out:
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ downsampling_hidden_1 (Dense)        │ (None, 256)                 │         200,960 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ downsampling_hidden_2 (Dense)        │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ latent (Dense)                       │ (None, 32)                  │           2,080 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 219,488 (857.38 KB)
#  Trainable params: 219,488 (857.38 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
## SUBMODEL FOR THE DECODER

# create the decoder model
decoder_model = Model(encoded, decoded)

decoder_model.summary()
# Out:
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ keras_tensor_10CLONE (InputLayer)    │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ upsampling_hidden_1 (Dense)          │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ upsampling_hidden_2 (Dense)          │ (None, 256)                 │          16,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ decoder (Dense)                      │ (None, 784)                 │         201,488 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 220,240 (860.31 KB)
#  Trainable params: 220,240 (860.31 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Training and Evaluation

# %%
#otherwise linear activation in the output and mse loss would work as well

autoencoder.compile(optimizer="adam", loss='binary_crossentropy', metrics = ["mse"])
autoencoder.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ downsampling_hidden_1 (Dense)        │ (None, 256)                 │         200,960 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ downsampling_hidden_2 (Dense)        │ (None, 64)                  │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ latent (Dense)                       │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ upsampling_hidden_1 (Dense)          │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ upsampling_hidden_2 (Dense)          │ (None, 256)                 │          16,640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ decoder (Dense)                      │ (None, 784)                 │         201,488 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 439,728 (1.68 MB)
#  Trainable params: 439,728 (1.68 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
#note: X_train, X_train :)
#also note: "encoder_model" and "decoder_model" are just "pointers" to the autoencoder main model. This means that when the AE is trained, the encoder and the decoder will point to the trained weights.
network_history = autoencoder.fit(X_train,X_train,
                epochs=100,
                batch_size=1024,
                shuffle=True,
                validation_split=0.1)
# Out:
# Epoch 1/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 7s 56ms/step - loss: 0.5597 - mse: 0.1136 - val_loss: 0.3754 - val_mse: 0.0459
# Epoch 2/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - loss: 0.3593 - mse: 0.0410 - val_loss: 0.3447 - val_mse: 0.0346
# Epoch 3/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3292 - mse: 0.0301 - val_loss: 0.3192 - val_mse: 0.0254
# Epoch 4/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3139 - mse: 0.0245 - val_loss: 0.3116 - val_mse: 0.0227
# Epoch 5/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3075 - mse: 0.0223 - val_loss: 0.3065 - val_mse: 0.0210
# Epoch 6/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3041 - mse: 0.0211 - val_loss: 0.3034 - val_mse: 0.0200
# Epoch 7/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2999 - mse: 0.0196 - val_loss: 0.3008 - val_mse: 0.0191
# Epoch 8/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2984 - mse: 0.0191 - val_loss: 0.2993 - val_mse: 0.0186
# Epoch 9/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2960 - mse: 0.0183 - val_loss: 0.2977 - val_mse: 0.0181
# Epoch 10/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2955 - mse: 0.0182 - val_loss: 0.2964 - val_mse: 0.0175
# Epoch 11/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2933 - mse: 0.0174 - val_loss: 0.2950 - val_mse: 0.0172
# Epoch 12/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2926 - mse: 0.0172 - val_loss: 0.2940 - val_mse: 0.0167
# Epoch 13/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2910 - mse: 0.0166 - val_loss: 0.2932 - val_mse: 0.0164
# Epoch 14/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2912 - mse: 0.0167 - val_loss: 0.2922 - val_mse: 0.0162
# Epoch 15/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2890 - mse: 0.0159 - val_loss: 0.2914 - val_mse: 0.0159
# Epoch 16/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2887 - mse: 0.0158 - val_loss: 0.2905 - val_mse: 0.0156
# Epoch 17/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2878 - mse: 0.0155 - val_loss: 0.2900 - val_mse: 0.0155
# Epoch 18/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2870 - mse: 0.0152 - val_loss: 0.2894 - val_mse: 0.0152
# Epoch 19/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.2864 - mse: 0.0150 - val_loss: 0.2890 - val_mse: 0.0150
# Epoch 20/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.2858 - mse: 0.0149 - val_loss: 0.2883 - val_mse: 0.0149
# Epoch 21/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.2852 - mse: 0.0147 - val_loss: 0.2881 - val_mse: 0.0148
# Epoch 22/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2848 - mse: 0.0145 - val_loss: 0.2876 - val_mse: 0.0146
# Epoch 23/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.2844 - mse: 0.0144 - val_loss: 0.2875 - val_mse: 0.0145
# Epoch 24/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2841 - mse: 0.0143 - val_loss: 0.2867 - val_mse: 0.0143
# Epoch 25/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2835 - mse: 0.0141 - val_loss: 0.2860 - val_mse: 0.0141
# Epoch 26/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2832 - mse: 0.0140 - val_loss: 0.2856 - val_mse: 0.0140
# Epoch 27/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2830 - mse: 0.0139 - val_loss: 0.2853 - val_mse: 0.0138
# Epoch 28/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2832 - mse: 0.0140 - val_loss: 0.2850 - val_mse: 0.0138
# Epoch 29/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2819 - mse: 0.0135 - val_loss: 0.2848 - val_mse: 0.0137
# Epoch 30/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2817 - mse: 0.0135 - val_loss: 0.2844 - val_mse: 0.0135
# Epoch 31/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2813 - mse: 0.0133 - val_loss: 0.2841 - val_mse: 0.0134
# Epoch 32/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2811 - mse: 0.0133 - val_loss: 0.2838 - val_mse: 0.0133
# Epoch 33/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2808 - mse: 0.0132 - val_loss: 0.2835 - val_mse: 0.0133
# Epoch 34/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2805 - mse: 0.0131 - val_loss: 0.2837 - val_mse: 0.0134
# Epoch 35/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2805 - mse: 0.0131 - val_loss: 0.2831 - val_mse: 0.0131
# Epoch 36/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2800 - mse: 0.0129 - val_loss: 0.2828 - val_mse: 0.0130
# Epoch 37/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2797 - mse: 0.0128 - val_loss: 0.2826 - val_mse: 0.0130
# Epoch 38/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2796 - mse: 0.0128 - val_loss: 0.2824 - val_mse: 0.0129
# Epoch 39/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2798 - mse: 0.0128 - val_loss: 0.2827 - val_mse: 0.0131
# Epoch 40/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2790 - mse: 0.0126 - val_loss: 0.2819 - val_mse: 0.0127
# Epoch 41/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2787 - mse: 0.0125 - val_loss: 0.2820 - val_mse: 0.0127
# Epoch 42/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2795 - mse: 0.0128 - val_loss: 0.2818 - val_mse: 0.0128
# Epoch 43/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2783 - mse: 0.0123 - val_loss: 0.2812 - val_mse: 0.0125
# Epoch 44/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2780 - mse: 0.0122 - val_loss: 0.2825 - val_mse: 0.0128
# Epoch 45/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - loss: 0.2785 - mse: 0.0124 - val_loss: 0.2808 - val_mse: 0.0124
# Epoch 46/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2780 - mse: 0.0122 - val_loss: 0.2807 - val_mse: 0.0123
# Epoch 47/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2775 - mse: 0.0121 - val_loss: 0.2804 - val_mse: 0.0122
# Epoch 48/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2779 - mse: 0.0122 - val_loss: 0.2804 - val_mse: 0.0123
# Epoch 49/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2772 - mse: 0.0119 - val_loss: 0.2802 - val_mse: 0.0122
# Epoch 50/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2770 - mse: 0.0119 - val_loss: 0.2799 - val_mse: 0.0120
# Epoch 51/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2768 - mse: 0.0118 - val_loss: 0.2797 - val_mse: 0.0120
# Epoch 52/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2766 - mse: 0.0118 - val_loss: 0.2795 - val_mse: 0.0119
# Epoch 53/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2765 - mse: 0.0117 - val_loss: 0.2794 - val_mse: 0.0119
# Epoch 54/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2762 - mse: 0.0116 - val_loss: 0.2792 - val_mse: 0.0118
# Epoch 55/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2761 - mse: 0.0116 - val_loss: 0.2802 - val_mse: 0.0121
# Epoch 56/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2761 - mse: 0.0116 - val_loss: 0.2796 - val_mse: 0.0119
# Epoch 57/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2759 - mse: 0.0115 - val_loss: 0.2789 - val_mse: 0.0118
# Epoch 58/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2767 - mse: 0.0118 - val_loss: 0.2790 - val_mse: 0.0118
# Epoch 59/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2755 - mse: 0.0114 - val_loss: 0.2785 - val_mse: 0.0116
# Epoch 60/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2755 - mse: 0.0114 - val_loss: 0.2783 - val_mse: 0.0115
# Epoch 61/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2753 - mse: 0.0113 - val_loss: 0.2782 - val_mse: 0.0115
# Epoch 62/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2751 - mse: 0.0113 - val_loss: 0.2781 - val_mse: 0.0115
# Epoch 63/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2749 - mse: 0.0112 - val_loss: 0.2780 - val_mse: 0.0114
# Epoch 64/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2750 - mse: 0.0112 - val_loss: 0.2780 - val_mse: 0.0114
# Epoch 65/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2748 - mse: 0.0112 - val_loss: 0.2779 - val_mse: 0.0114
# Epoch 66/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2749 - mse: 0.0112 - val_loss: 0.2776 - val_mse: 0.0113
# Epoch 67/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2748 - mse: 0.0112 - val_loss: 0.2783 - val_mse: 0.0117
# Epoch 68/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2745 - mse: 0.0111 - val_loss: 0.2781 - val_mse: 0.0116
# Epoch 69/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.2744 - mse: 0.0110 - val_loss: 0.2779 - val_mse: 0.0115
# Epoch 70/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2743 - mse: 0.0110 - val_loss: 0.2778 - val_mse: 0.0115
# Epoch 71/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2742 - mse: 0.0110 - val_loss: 0.2775 - val_mse: 0.0113
# Epoch 72/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - loss: 0.2740 - mse: 0.0109 - val_loss: 0.2772 - val_mse: 0.0112
# Epoch 73/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2739 - mse: 0.0109 - val_loss: 0.2770 - val_mse: 0.0111
# Epoch 74/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2737 - mse: 0.0108 - val_loss: 0.2768 - val_mse: 0.0111
# Epoch 75/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2738 - mse: 0.0108 - val_loss: 0.2768 - val_mse: 0.0110
# Epoch 76/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2736 - mse: 0.0108 - val_loss: 0.2767 - val_mse: 0.0110
# Epoch 77/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2735 - mse: 0.0107 - val_loss: 0.2767 - val_mse: 0.0110
# Epoch 78/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2735 - mse: 0.0107 - val_loss: 0.2765 - val_mse: 0.0110
# Epoch 79/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2734 - mse: 0.0107 - val_loss: 0.2764 - val_mse: 0.0109
# Epoch 80/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2733 - mse: 0.0107 - val_loss: 0.2763 - val_mse: 0.0109
# Epoch 81/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2732 - mse: 0.0106 - val_loss: 0.2763 - val_mse: 0.0109
# Epoch 82/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2730 - mse: 0.0106 - val_loss: 0.2763 - val_mse: 0.0109
# Epoch 83/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2735 - mse: 0.0107 - val_loss: 0.2761 - val_mse: 0.0108
# Epoch 84/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2730 - mse: 0.0106 - val_loss: 0.2760 - val_mse: 0.0108
# Epoch 85/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2728 - mse: 0.0105 - val_loss: 0.2761 - val_mse: 0.0109
# Epoch 86/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2727 - mse: 0.0105 - val_loss: 0.2761 - val_mse: 0.0109
# Epoch 87/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2727 - mse: 0.0105 - val_loss: 0.2760 - val_mse: 0.0108
# Epoch 88/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2726 - mse: 0.0104 - val_loss: 0.2759 - val_mse: 0.0108
# Epoch 89/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2725 - mse: 0.0104 - val_loss: 0.2757 - val_mse: 0.0107
# Epoch 90/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.2724 - mse: 0.0104 - val_loss: 0.2755 - val_mse: 0.0106
# Epoch 91/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2722 - mse: 0.0103 - val_loss: 0.2754 - val_mse: 0.0106
# Epoch 92/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2724 - mse: 0.0104 - val_loss: 0.2756 - val_mse: 0.0107
# Epoch 93/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2722 - mse: 0.0103 - val_loss: 0.2753 - val_mse: 0.0106
# Epoch 94/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2720 - mse: 0.0103 - val_loss: 0.2753 - val_mse: 0.0105
# Epoch 95/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.2724 - mse: 0.0104 - val_loss: 0.2757 - val_mse: 0.0108
# Epoch 96/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.2722 - mse: 0.0103 - val_loss: 0.2756 - val_mse: 0.0107
# Epoch 97/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.2720 - mse: 0.0102 - val_loss: 0.2753 - val_mse: 0.0106
# Epoch 98/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.2719 - mse: 0.0102 - val_loss: 0.2751 - val_mse: 0.0105
# Epoch 99/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.2717 - mse: 0.0102 - val_loss: 0.2750 - val_mse: 0.0105
# Epoch 100/100
# 53/53 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.2717 - mse: 0.0101 - val_loss: 0.2749 - val_mse: 0.0104

# %% [markdown]
# ### Testing the Autoencoder

# %%
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
x_selected = x_test
encoded_imgs = encoder_model.predict(x_selected)
decoded_imgs = decoder_model.predict(encoded_imgs)

#autoencoder.predict(x_selected)
#alternative here?
#decoded_imgs = autoencoder.predict(x_selected)
n = 10
plt.figure(figsize=(20, 4))
for i in range(n):
    # original
    ax = plt.subplot(2, n, i + 1)
    plt.imshow(x_selected[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # reconstruction
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

pred = autoencoder.predict(x_selected)

print(mean_absolute_error(x_test, pred))
print(mean_squared_error(x_test, pred))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 0.052211374
# 0.010367722

# %% [markdown]
# ### Sample generation with Autoencoder

# %% [markdown]
# One of the powerful tools of auto-encoders is using the encoder to generate meaningful representation from the feature vectors.

# %%
n = 20

random_encodings = np.random.rand(20,encoding_dim)
decoded_imgs = decoder_model.predict(random_encodings)

plt.figure(figsize=(20, 4))
for i in range(n):
    # generation
    ax = plt.subplot(2, n, i + 1 + n)
    plt.imshow(decoded_imgs[i].reshape(28, 28))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step

# %% [markdown]
# ## Latent Representations

# %% [markdown]
# For some samples in `X_train`, we will **extract the latent features** (encodings) of the trained autoencoder model and compare these representations with classic dimensionality reduction techniques such as PCA and TSNE.

# %%
#we select four classes/labels for better visualization
selected_labels = [0,1,2]

train_selected_idxs = np.in1d(y_train, selected_labels)
val_selected_idxs = np.in1d(y_train, selected_labels)
X_train = X_train[train_selected_idxs]
y_train = y_train[train_selected_idxs]
X_train = X_train[:1000] #just for computational cost
y_train = y_train[:1000]

X_train.shape, y_train.shape, np.unique(y_train, return_counts = True)
# Out:
# ((1000, 784), (1000,), (array([0, 1, 2], dtype=uint8), array([313, 362, 325])))

# %% [markdown]
# #### TSNE and PCA
#
# applied on `X_train`

# %%
from sklearn.manifold import TSNE

tsne = TSNE(n_components=2)
X_train_tsne = tsne.fit_transform(X_train) ## Reduced for computational issues

# %%
X_train_tsne.shape
# Out:
# (60000, 2)

# %%
from sklearn import decomposition
pca = decomposition.PCA(n_components=2)
X_train_pca = pca.fit_transform(X_train)

# %% [markdown]
# ### Extracting the AE encodings

# %%
AE_encodings = encoder_model.predict(X_train)
AE_encodings.shape
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# (1000, 32)

# %%
tsne = TSNE(n_components=2)
AE_encodings_tsne = tsne.fit_transform(AE_encodings)
pca = decomposition.PCA(n_components=2)
AE_encodings_pca = pca.fit_transform(AE_encodings)

# %% [markdown]
# ### Visualize

# %%
#utility for plots
import plotly.express as px

def plot_data(X, y, title, is_3d = False):
  if not is_3d:
    fig = px.scatter(
        X, x=0, y=1, title=title,
        color=y, labels={'color': 'classes'})
    fig.update_traces(marker_size=6)

  else:
    fig = px.scatter_3d(
    X, x=0, y=1, z=2, title=title,
    color=y, labels={'color': 'classes'})
    fig.update_traces(marker_size=2)
  fig.show()

# %%
plot_data(X_train_tsne, y_train, title="TSNE", is_3d = False)
plot_data(X_train_pca, y_train, title="PCA", is_3d = False)
plot_data(AE_encodings[:, :2], y_train, title="Latent", is_3d = False)
plot_data(AE_encodings_tsne, y_train, title="TSNE + Latent", is_3d = False)
plot_data(AE_encodings_pca, y_train, title="PCA+Latent", is_3d = False)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="89b721d5-20d6-4a43-9e97-45e989a95e32" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("89b721d5-20d6-4a43-9e97-45e989a95e32")) {                    Plotly.newPlot(                        "89b721d5-20d6-4a43-9e97-45e989a95e32",                        [{"hovertemplate":"classes=0\u003cbr\u003e0=%{x}\u003cbr\u003e1=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"0","marker":{"color":"#636efa","symbol":"circle","size":6},"mode":"markers","name":"0","orientation":"v","showlegend":true,"x":[12.5811128616333,-5.949374675750732,-11.190278053283691,5.501208782196045,10.896666526794434,10.71550178527832,-0.16380354762077332,7.6303253173828125,8.52120590209961,-5.971728324890137,10.397661209106445,-7.86713981628418,-6.658614635467529,16.48294448852539,10.778369903564453,-24.800230026245117,27.499286651611328,16.77352523803711,11.594707489013672,4.741086483001709,5.598237991333008,-11.51602554321289,2.5676605701446533,10.868422508239746,0.29196882247924805,0.8144795894622803,13.887724876403809,-9.380467414855957,6.254581928253174,12.051803588867188,39.14247512817383,11.479787826538086,7.234121799468994,14.842326164245605,4.07346248626709,-2.7912025451660156,9.986316680908203,19.697200775146484,4.799352645874023,6.301326274871826,-6.239181995391846,-7.697447299957275,-9.864811897277832,8.7239351272583,1.6704888343811035,-1.9840686321258545,5.362837314605713,3.918257236480713,-5.680853366851807,6.068582057952881,1.8286118507385254,10.786182403564453,4.906068325042725,-0.09811852127313614,14.398059844970703,1.608389139175415,7.513428688049316,2.4151904582977295,11.109108924865723,2.927733898162842,-6.560303688049316,4.11233377456665,-1.1669890880584717,-10.081507682800293,-5.291295528411865,13.992515563964844,15.933365821838379,2.390153169631958,13.220699310302734,14.286913871765137,4.449429035186768,8.004268646240234,3.406156539916992,5.38719367980957,6.2942328453063965,16.121374130249023,13.569205284118652,11.581170082092285,16.190820693969727,11.615412712097168,2.9752249717712402,-8.476433753967285,-8.295042991638184,16.867162704467773,8.790369987487793,13.525540351867676,12.198092460632324,10.251945495605469,14.013415336608887,-5.927463531494141,0.9378224611282349,15.41625690460205,-2.974365234375,1.4120233058929443,12.763982772
12.973925590515137,-10.579483032226562,4.727268218994141,-3.664142608642578,-14.065783500671387,-4.671321868896484,-12.31334114074707,-9.194351196289062,-1.2881088256835938,-11.53542709350586,-5.707149505615234,3.2867374420166016,-12.660867691040039,-7.26820182800293,6.489971160888672,-4.7647857666015625,-7.272926330566406,-7.394329071044922,-10.632789611816406,-5.104351043701172,-1.2949256896972656,-2.184354782104492,-16.65886688232422,-0.1238861083984375,-13.890816688537598,-11.523381233215332,-7.741901397705078,-6.224067687988281,1.796234130859375,-3.4011993408203125,1.5733108520507812,-5.553218841552734,3.3869781494140625,3.0819473266601562,-4.84016227722168,-5.435703277587891,-3.8048934936523438,-2.46038818359375,-10.770553588867188,-3.4254837036132812,-3.6161346435546875,-21.876502990722656,-1.321868896484375,-7.550262451171875,-10.940284729003906,-5.842138290405273,-0.0043792724609375,-16.715892791748047,-2.231609344482422,-3.653911590576172,-4.266279220581055,-15.456493377685547,-7.827985763549805,-10.193809509277344,-1.2474632263183594,-15.023618698120117,-12.869037628173828,-14.042646408081055,1.0893383026123047,-11.726312637329102,-13.68354320526123,-4.362781524658203,-4.732349395751953,-6.47906494140625,-0.00887298583984375,-15.76492977142334,-14.139735221862793,-6.303653717041016,-0.8087997436523438,-16.65011978149414,-13.677738189697266,-11.12093734741211,-5.128551483154297,5.05401611328125,-5.924705505371094,-12.205747604370117,-8.530014038085938,-11.574714660644531,-8.773578643798828,-2.456613540649414,-12.820029258728027,-4.571800231933594,-13.654411315917969,0.9397029876708984,-0.7890548706054688,-8.242767333984375,-6.410001754760742,-13.01474380493164,-14.184940338134766,-6.123928070068359,-8.101808547973633,-0.3908119201660156,-10.155366897583008,-3.4237594604492188,1.3130779266357422,7.288105010986328,-12.24808120727539,-8.584733963012695,-2.3267154693603516,-16.845203399658203,-4.566198348999023,-9.567586898803711,2.81591796875,-12.413694381713867,-7.814218521118164,-8.53060531616211,9.54494857788086,-12.199989318847656,-11.461225509643555,-3.593231201171875,-4.897518157958984,-12.706050872802734,-18.278533935546875,-3.3500442504882812,-6.818454742431641,-4.907802581787109,-11.0 ...

# %%
def plot_data(data, labels, title = "nonlinear data"):
    # Generate scatter plot for training data
    fig, ax = plt.subplots(figsize=(10,10))
    for g in np.unique(labels):
        i = np.where(labels == g)
        ax.scatter(data[i,0], data[i,1], label=g)
    plt.title(title)
    plt.xlabel("X1")
    plt.ylabel("X2")
    plt.legend()

    plt.show()

plot_data(X_train_tsne, y_train, title = "Tsne on X_train")
plot_data(X_train_pca, y_train, title = "PCA on X_train")
plot_data(AE_encodings[:, :2], y_train, title = "AE encodings (first 2 components)")
plot_data(AE_encodings_tsne, y_train, title = "tse on AE encodings")
plot_data(AE_encodings_pca, y_train, title = "PCA on AE encodings")

# %% [markdown]
# ## 📕 Exercise
#
# Take a dataset from keras or kaggle (make sure you take a dataset with high dimensionality).
# Build an autoencoder on this dataset.
# Extract the latent representation and use it to classify the dataset with classical ML models. Compare the results of the "latent representation" with those of PCA or some other dimensionality reduction technique.
